# %%
import matplotlib.pyplot as plt
import networkx as nx

# Tạo đồ thị
G = nx.DiGraph()

# Thêm các nút (bước trong quy trình)
nodes = [
    "Kỹ sư cần thuê thiết bị", "Gửi Y/C thuê thiết bị (Mail)", "Nhân viên kho nhận yêu cầu",
    "Chọn thiết bị phù hợp", "Kiểm tra tồn kho NCC", "Thiết bị không có sẵn",
    "Chọn thiết bị thay thế", "Kiểm tra tồn kho thiết bị thay thế", "Thiết bị có sẵn",
    "Thêm chi tiết vào Y/C thuê", "Chuyển Y/C thuê đến kỹ sư công trình",
    "Đợi phê duyệt", "Không duyệt", "Hủy yêu cầu", "Không thuê thiết bị",
    "Thay thiết bị khác", "Quay lại kiểm tra tồn kho", "Duyệt",
    "Xác nhận PO", "Tạo PO", "Theo dõi PO", "Hủy PO", "NCC giao thiết bị",
    "Kiểm tra thiết bị", "Đạt yêu cầu", "Chấp nhận & sử dụng",
    "Thủ tục nhập kho & xuất kho", "Không đạt yêu cầu", "Trả lại NCC",
    "Quay lại quy trình thuê từ đầu", "Hết thời gian thuê", "Yêu cầu gia hạn",
    "Liên hệ NCC", "NCC đồng ý", "Tiếp tục thuê", "NCC không đồng ý",
    "Hoàn trả & Thu hồi thiết bị", "Nhân viên kho xác nhận với kỹ sư công trường",
    "Kiểm tra hóa đơn", "Chuyển đến phòng tài chính", "Thanh toán hóa đơn"
]

# Thêm các cạnh (quan hệ giữa các bước)
edges = [
    ("Kỹ sư cần thuê thiết bị", "Gửi Y/C thuê thiết bị (Mail)"),
    ("Gửi Y/C thuê thiết bị (Mail)", "Nhân viên kho nhận yêu cầu"),
    ("Nhân viên kho nhận yêu cầu", "Chọn thiết bị phù hợp"),
    ("Chọn thiết bị phù hợp", "Kiểm tra tồn kho NCC"),
    ("Kiểm tra tồn kho NCC", "Thiết bị không có sẵn"),
    ("Thiết bị không có sẵn", "Chọn thiết bị thay thế"),
    ("Chọn thiết bị thay thế", "Kiểm tra tồn kho thiết bị thay thế"),
    ("Kiểm tra tồn kho NCC", "Thiết bị có sẵn"),
    ("Thiết bị có sẵn", "Thêm chi tiết vào Y/C thuê"),
    ("Thêm chi tiết vào Y/C thuê", "Chuyển Y/C thuê đến kỹ sư công trình"),
    ("Chuyển Y/C thuê đến kỹ sư công trình", "Đợi phê duyệt"),
    ("Đợi phê duyệt", "Không duyệt"),
    ("Không duyệt", "Hủy yêu cầu"),
    ("Hủy yêu cầu", "Không thuê thiết bị"),
    ("Không duyệt", "Thay thiết bị khác"),
    ("Thay thiết bị khác", "Quay lại kiểm tra tồn kho"),
    ("Đợi phê duyệt", "Duyệt"),
    ("Duyệt", "Xác nhận PO"),
    ("Xác nhận PO", "Tạo PO"),
    ("Tạo PO", "Theo dõi PO"),
    ("Theo dõi PO", "Hủy PO"),
    ("Theo dõi PO", "NCC giao thiết bị"),
    ("NCC giao thiết bị", "Kiểm tra thiết bị"),
    ("Kiểm tra thiết bị", "Đạt yêu cầu"),
    ("Đạt yêu cầu", "Chấp nhận & sử dụng"),
    ("Chấp nhận & sử dụng", "Thủ tục nhập kho & xuất kho"),
    ("Kiểm tra thiết bị", "Không đạt yêu cầu"),
    ("Không đạt yêu cầu", "Trả lại NCC"),
    ("Trả lại NCC", "Quay lại quy trình thuê từ đầu"),
    ("Chấp nhận & sử dụng", "Hết thời gian thuê"),
    ("Hết thời gian thuê", "Yêu cầu gia hạn"),
    ("Yêu cầu gia hạn", "Liên hệ NCC"),
    ("Liên hệ NCC", "NCC đồng ý"),
    ("NCC đồng ý", "Tiếp tục thuê"),
    ("Liên hệ NCC", "NCC không đồng ý"),
    ("NCC không đồng ý", "Hoàn trả & Thu hồi thiết bị"),
    ("Hoàn trả & Thu hồi thiết bị", "Nhân viên kho xác nhận với kỹ sư công trường"),
    ("Nhân viên kho xác nhận với kỹ sư công trường", "Kiểm tra hóa đơn"),
    ("Kiểm tra hóa đơn", "Chuyển đến phòng tài chính"),
    ("Chuyển đến phòng tài chính", "Thanh toán hóa đơn")
]

# Thêm các nút và cạnh vào đồ thị
G.add_nodes_from(nodes)
G.add_edges_from(edges)

# Vẽ đồ thị
plt.figure(figsize=(20, 12))
pos = nx.spring_layout(G, seed=42, k=0.8)  # Layout đồ thị
nx.draw(G, pos, with_labels=True, node_size=4000, node_color="lightblue", font_size=8, edge_color="gray")
plt.title("Sơ đồ Quy Trình Thuê Thiết Bị - BuildIT", fontsize=12)
plt.show()

# %%
# Re-import necessary libraries after execution state reset
import matplotlib.pyplot as plt
import networkx as nx

# Tạo đồ thị
G = nx.DiGraph()

# Thêm các nút (bước trong quy trình)
nodes = [
    "Kỹ sư cần thuê thiết bị", "Gửi Y/C thuê thiết bị (Mail)", "Nhân viên kho nhận yêu cầu",
    "Chọn thiết bị phù hợp", "Kiểm tra tồn kho NCC", "Thiết bị không có sẵn",
    "Chọn thiết bị thay thế", "Kiểm tra tồn kho thiết bị thay thế", "Thiết bị có sẵn",
    "Thêm chi tiết vào Y/C thuê", "Chuyển Y/C thuê đến kỹ sư công trình",
    "Đợi phê duyệt", "Không duyệt", "Hủy yêu cầu", "Không thuê thiết bị",
    "Thay thiết bị khác", "Quay lại kiểm tra tồn kho", "Duyệt",
    "Xác nhận PO", "Tạo PO", "Theo dõi PO", "Hủy PO", "NCC giao thiết bị",
    "Kiểm tra thiết bị", "Đạt yêu cầu", "Chấp nhận & sử dụng",
    "Thủ tục nhập kho & xuất kho", "Không đạt yêu cầu", "Trả lại NCC",
    "Quay lại quy trình thuê từ đầu", "Hết thời gian thuê", "Yêu cầu gia hạn",
    "Liên hệ NCC", "NCC đồng ý", "Tiếp tục thuê", "NCC không đồng ý",
    "Hoàn trả & Thu hồi thiết bị", "Nhân viên kho xác nhận với kỹ sư công trường",
    "Kiểm tra hóa đơn", "Chuyển đến phòng tài chính", "Thanh toán hóa đơn"
]

# Thêm các cạnh (quan hệ giữa các bước)
edges = [
    ("Kỹ sư cần thuê thiết bị", "Gửi Y/C thuê thiết bị (Mail)"),
    ("Gửi Y/C thuê thiết bị (Mail)", "Nhân viên kho nhận yêu cầu"),
    ("Nhân viên kho nhận yêu cầu", "Chọn thiết bị phù hợp"),
    ("Chọn thiết bị phù hợp", "Kiểm tra tồn kho NCC"),
    ("Kiểm tra tồn kho NCC", "Thiết bị không có sẵn"),
    ("Thiết bị không có sẵn", "Chọn thiết bị thay thế"),
    ("Chọn thiết bị thay thế", "Kiểm tra tồn kho thiết bị thay thế"),
    ("Kiểm tra tồn kho NCC", "Thiết bị có sẵn"),
    ("Thiết bị có sẵn", "Thêm chi tiết vào Y/C thuê"),
    ("Thêm chi tiết vào Y/C thuê", "Chuyển Y/C thuê đến kỹ sư công trình"),
    ("Chuyển Y/C thuê đến kỹ sư công trình", "Đợi phê duyệt"),
    ("Đợi phê duyệt", "Không duyệt"),
    ("Không duyệt", "Hủy yêu cầu"),
    ("Hủy yêu cầu", "Không thuê thiết bị"),
    ("Không duyệt", "Thay thiết bị khác"),
    ("Thay thiết bị khác", "Quay lại kiểm tra tồn kho"),
    ("Đợi phê duyệt", "Duyệt"),
    ("Duyệt", "Xác nhận PO"),
    ("Xác nhận PO", "Tạo PO"),
    ("Tạo PO", "Theo dõi PO"),
    ("Theo dõi PO", "Hủy PO"),
    ("Theo dõi PO", "NCC giao thiết bị"),
    ("NCC giao thiết bị", "Kiểm tra thiết bị"),
    ("Kiểm tra thiết bị", "Đạt yêu cầu"),
    ("Đạt yêu cầu", "Chấp nhận & sử dụng"),
    ("Chấp nhận & sử dụng", "Thủ tục nhập kho & xuất kho"),
    ("Kiểm tra thiết bị", "Không đạt yêu cầu"),
    ("Không đạt yêu cầu", "Trả lại NCC"),
    ("Trả lại NCC", "Quay lại quy trình thuê từ đầu"),
    ("Chấp nhận & sử dụng", "Hết thời gian thuê"),
    ("Hết thời gian thuê", "Yêu cầu gia hạn"),
    ("Yêu cầu gia hạn", "Liên hệ NCC"),
    ("Liên hệ NCC", "NCC đồng ý"),
    ("NCC đồng ý", "Tiếp tục thuê"),
    ("Liên hệ NCC", "NCC không đồng ý"),
    ("NCC không đồng ý", "Hoàn trả & Thu hồi thiết bị"),
    ("Hoàn trả & Thu hồi thiết bị", "Nhân viên kho xác nhận với kỹ sư công trường"),
    ("Nhân viên kho xác nhận với kỹ sư công trường", "Kiểm tra hóa đơn"),
    ("Kiểm tra hóa đơn", "Chuyển đến phòng tài chính"),
    ("Chuyển đến phòng tài chính", "Thanh toán hóa đơn")
]

# Thêm các nút và cạnh vào đồ thị
G.add_nodes_from(nodes)
G.add_edges_from(edges)

# Vẽ đồ thị
plt.figure(figsize=(20, 12))
pos = nx.spring_layout(G, seed=42, k=0.8)  # Layout đồ thị
nx.draw(G, pos, with_labels=True, node_size=3000, node_color="lightblue", font_size=8, edge_color="gray")
plt.title("Sơ đồ Quy Trình Thuê Thiết Bị - BuildIT", fontsize=14)
plt.show()

# %%
# Vẽ lại sơ đồ quy trình thuê thiết bị cho BuildIT

plt.figure(figsize=(20, 12))
pos = nx.spring_layout(G, seed=42, k=0.8)  # Layout đồ thị
nx.draw(G, pos, with_labels=True, node_size=3000, node_color="lightblue", font_size=8, edge_color="gray")
plt.title("Sơ đồ Quy Trình Thuê Thiết Bị - BuildIT", fontsize=14)
plt.show()

# %%
# Lưu sơ đồ quy trình thuê thiết bị dưới dạng tệp hình ảnh

plt.figure(figsize=(20, 12))
pos = nx.spring_layout(G, seed=42, k=0.8)  # Layout đồ thị
nx.draw(G, pos, with_labels=True, node_size=3000, node_color="lightblue", font_size=8, edge_color="gray")
plt.title("Sơ đồ Quy Trình Thuê Thiết Bị - BuildIT", fontsize=14)

# Lưu hình ảnh vào tệp
image_path = r"D:\01.UIT\07.HK7\HTQT.png"
plt.savefig(image_path, format="png")
plt.close()

# Trả về đường dẫn tải xuống
image_path
# Out:
# 'D:\\01.UIT\\07.HK7\\HTQT.png'

# %%
# Tạo lại sơ đồ và lưu dưới dạng hình ảnh

# Vẽ sơ đồ
plt.figure(figsize=(20, 12))
pos = nx.spring_layout(G, seed=42, k=0.8)  # Bố cục đồ thị
nx.draw(G, pos, with_labels=True, node_size=3000, node_color="lightblue", font_size=8, edge_color="gray")
plt.title("Sơ đồ Quy Trình Thuê Thiết Bị - BuildIT", fontsize=14)

# Lưu hình ảnh vào tệp
image_file_path = r"D:\01.UIT\07.HK7\HTQT.png"
plt.savefig(image_file_path, format="png")
plt.close()

# Trả về đường dẫn để người dùng tải xuống
image_file_path
# Out:
# 'D:\\01.UIT\\07.HK7\\HTQT.png'

# %%
# Vẽ lại sơ đồ quy trình theo dạng khối có liên kết rõ ràng

# Khởi tạo đồ thị có hướng
G = nx.DiGraph()

# Xác định các nhóm quy trình chính
process_blocks = {
    "1. Yêu cầu thiết bị": ["Kỹ sư cần thuê thiết bị", "Gửi Y/C thuê thiết bị (Mail)", "Nhân viên kho nhận yêu cầu"],
    "2. Xác nhận thiết bị": ["Chọn thiết bị phù hợp", "Kiểm tra tồn kho NCC", "Thiết bị không có sẵn", "Chọn thiết bị thay thế", "Kiểm tra tồn kho thiết bị thay thế", "Thiết bị có sẵn"],
    "3. Phê duyệt yêu cầu": ["Thêm chi tiết vào Y/C thuê", "Chuyển Y/C thuê đến kỹ sư công trình", "Đợi phê duyệt", "Không duyệt", "Hủy yêu cầu", "Không thuê thiết bị", "Thay thiết bị khác", "Quay lại kiểm tra tồn kho", "Duyệt"],
    "4. Đặt hàng và giao nhận": ["Xác nhận PO", "Tạo PO", "Theo dõi PO", "Hủy PO", "NCC giao thiết bị", "Kiểm tra thiết bị"],
    "5. Sử dụng và kiểm tra": ["Đạt yêu cầu", "Chấp nhận & sử dụng", "Thủ tục nhập kho & xuất kho", "Không đạt yêu cầu", "Trả lại NCC", "Quay lại quy trình thuê từ đầu"],
    "6. Hết thời gian thuê": ["Hết thời gian thuê", "Yêu cầu gia hạn", "Liên hệ NCC", "NCC đồng ý", "Tiếp tục thuê", "NCC không đồng ý", "Hoàn trả & Thu hồi thiết bị", "Nhân viên kho xác nhận với kỹ sư công trường"],
    "7. Thanh toán": ["Kiểm tra hóa đơn", "Chuyển đến phòng tài chính", "Thanh toán hóa đơn"]
}

# Thêm các nút theo nhóm vào đồ thị
for block, steps in process_blocks.items():
    G.add_nodes_from(steps)

# Xác định các liên kết chính giữa các bước trong quy trình
edges = [
    ("Kỹ sư cần thuê thiết bị", "Gửi Y/C thuê thiết bị (Mail)"),
    ("Gửi Y/C thuê thiết bị (Mail)", "Nhân viên kho nhận yêu cầu"),
    ("Nhân viên kho nhận yêu cầu", "Chọn thiết bị phù hợp"),
    ("Chọn thiết bị phù hợp", "Kiểm tra tồn kho NCC"),
    ("Kiểm tra tồn kho NCC", "Thiết bị không có sẵn"),
    ("Thiết bị không có sẵn", "Chọn thiết bị thay thế"),
    ("Chọn thiết bị thay thế", "Kiểm tra tồn kho thiết bị thay thế"),
    ("Kiểm tra tồn kho NCC", "Thiết bị có sẵn"),
    ("Thiết bị có sẵn", "Thêm chi tiết vào Y/C thuê"),
    ("Thêm chi tiết vào Y/C thuê", "Chuyển Y/C thuê đến kỹ sư công trình"),
    ("Chuyển Y/C thuê đến kỹ sư công trình", "Đợi phê duyệt"),
    ("Đợi phê duyệt", "Không duyệt"),
    ("Không duyệt", "Hủy yêu cầu"),
    ("Hủy yêu cầu", "Không thuê thiết bị"),
    ("Không duyệt", "Thay thiết bị khác"),
    ("Thay thiết bị khác", "Quay lại kiểm tra tồn kho"),
    ("Đợi phê duyệt", "Duyệt"),
    ("Duyệt", "Xác nhận PO"),
    ("Xác nhận PO", "Tạo PO"),
    ("Tạo PO", "Theo dõi PO"),
    ("Theo dõi PO", "Hủy PO"),
    ("Theo dõi PO", "NCC giao thiết bị"),
    ("NCC giao thiết bị", "Kiểm tra thiết bị"),
    ("Kiểm tra thiết bị", "Đạt yêu cầu"),
    ("Đạt yêu cầu", "Chấp nhận & sử dụng"),
    ("Chấp nhận & sử dụng", "Thủ tục nhập kho & xuất kho"),
    ("Kiểm tra thiết bị", "Không đạt yêu cầu"),
    ("Không đạt yêu cầu", "Trả lại NCC"),
    ("Trả lại NCC", "Quay lại quy trình thuê từ đầu"),
    ("Chấp nhận & sử dụng", "Hết thời gian thuê"),
    ("Hết thời gian thuê", "Yêu cầu gia hạn"),
    ("Yêu cầu gia hạn", "Liên hệ NCC"),
    ("Liên hệ NCC", "NCC đồng ý"),
    ("NCC đồng ý", "Tiếp tục thuê"),
    ("Liên hệ NCC", "NCC không đồng ý"),
    ("NCC không đồng ý", "Hoàn trả & Thu hồi thiết bị"),
    ("Hoàn trả & Thu hồi thiết bị", "Nhân viên kho xác nhận với kỹ sư công trường"),
    ("Nhân viên kho xác nhận với kỹ sư công trường", "Kiểm tra hóa đơn"),
    ("Kiểm tra hóa đơn", "Chuyển đến phòng tài chính"),
    ("Chuyển đến phòng tài chính", "Thanh toán hóa đơn")
]

# Thêm các cạnh vào đồ thị
G.add_edges_from(edges)

# Vẽ sơ đồ với cách tổ chức rõ ràng hơn
plt.figure(figsize=(20, 15))
pos = nx.multipartite_layout(G, subset_key=lambda n: next((i for i, b in enumerate(process_blocks) if n in process_blocks[b]), 0))
nx.draw(G, pos, with_labels=True, node_size=3000, node_color="lightblue", font_size=8, edge_color="gray", arrows=True)
plt.title("Sơ đồ Quy Trình Thuê Thiết Bị - BuildIT (Tối ưu hóa dạng khối)", fontsize=14)

# Lưu hình ảnh sơ đồ mới
image_path = r"D:\01.UIT\07.HK7\HTQT.png"
plt.savefig(image_path, format="png")
plt.close()

# Trả về đường dẫn tải về
image_path
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\networkx\drawing\layout.py:1084, in multipartite_layout(G, subset_key, align, scale, center)
#    1082 try:
#    1083     # check if subset_key is dict-like
# -> 1084     if len(G) != sum(len(nodes) for nodes in subset_key.values()):
#    1085         raise nx.NetworkXError(
#    1086             "all nodes must be in one subset of `subset_key` dict"
#    1087         )
#
# AttributeError: 'function' object has no attribute 'values'
#
# During handling of the above exception, another exception occurred:
#
# NetworkXError                             Traceback (most recent call last)
# Cell In[13], line 70
#      68 # Vẽ sơ đồ với cách tổ chức rõ ràng hơn
#      69 plt.figure(figsize=(20, 15))
# ...

# %%
# Vẽ sơ đồ quy trình thuê thiết bị theo mẫu sơ đồ quy trình cung cấp

# Xóa đồ thị cũ và khởi tạo lại đồ thị có hướng
G = nx.DiGraph()

# Định nghĩa các bước trong quy trình thuê thiết bị BuildIT
steps = {
    "Bắt đầu": "Kỹ sư cần thuê thiết bị",
    "Tiếp nhận yêu cầu": "Gửi Y/C thuê thiết bị (Mail)",
    "Phân công nhiệm vụ": "Nhân viên kho nhận yêu cầu",
    "Xây dựng kế hoạch": "Chọn thiết bị phù hợp",
    "Duyệt": "Kiểm tra tồn kho NCC",
    "Tổng hợp báo cáo": "Thiết bị không có sẵn",
    "Thực hiện theo kế hoạch": "Thiết bị có sẵn",
    "Xác minh": "Đợi phê duyệt",
    "Phương án xử lý": "Không duyệt / Duyệt",
    "Phân công xử lý": "Xác nhận PO & tạo PO",
    "Kiểm tra đánh giá": "Kiểm tra thiết bị khi nhận",
    "Báo cáo & lưu hồ sơ": "Hóa đơn & Thanh toán",
    "Kết thúc": "Kết thúc quy trình"
}

# Thêm các bước vào đồ thị
for key, value in steps.items():
    G.add_node(value)

# Xác định các luồng quy trình
edges = [
    ("Kỹ sư cần thuê thiết bị", "Gửi Y/C thuê thiết bị (Mail)"),
    ("Gửi Y/C thuê thiết bị (Mail)", "Nhân viên kho nhận yêu cầu"),
    ("Nhân viên kho nhận yêu cầu", "Chọn thiết bị phù hợp"),
    ("Chọn thiết bị phù hợp", "Kiểm tra tồn kho NCC"),
    ("Kiểm tra tồn kho NCC", "Thiết bị có sẵn"),
    ("Kiểm tra tồn kho NCC", "Thiết bị không có sẵn"),
    ("Thiết bị không có sẵn", "Chọn thiết bị thay thế"),
    ("Chọn thiết bị thay thế", "Kiểm tra tồn kho NCC"),
    ("Thiết bị có sẵn", "Đợi phê duyệt"),
    ("Đợi phê duyệt", "Không duyệt / Duyệt"),
    ("Không duyệt / Duyệt", "Xác nhận PO & tạo PO"),
    ("Xác nhận PO & tạo PO", "Theo dõi PO"),
    ("Theo dõi PO", "Kiểm tra thiết bị khi nhận"),
    ("Kiểm tra thiết bị khi nhận", "Hóa đơn & Thanh toán"),
    ("Hóa đơn & Thanh toán", "Kết thúc quy trình")
]

# Thêm các cạnh vào đồ thị
G.add_edges_from(edges)

# Vẽ sơ đồ theo bố cục dạng khối
plt.figure(figsize=(18, 10))
pos = nx.shell_layout(G)  # Bố cục dạng vòng tròn giúp nhóm các bước
nx.draw(G, pos, with_labels=True, node_size=3500, node_color="lightblue", font_size=10, edge_color="gray", arrows=True)
plt.title("Sơ đồ Quy Trình Thuê Thiết Bị - BuildIT (Dạng Khối)", fontsize=14)

# Lưu sơ đồ thành tệp
image_path = r"D:\01.UIT\07.HK7\HTQT_2.png"
plt.savefig(image_path, format="png")
plt.close()

# Trả về đường dẫn để tải xuống
image_path
# Out:
# 'D:\\01.UIT\\07.HK7\\HTQT_2.png'

# %%
# Vẽ lại sơ đồ quy trình thuê thiết bị với bố cục dạng hàng ngang cho dễ đọc

# Định nghĩa bố cục dạng hàng ngang
plt.figure(figsize=(20, 12))
pos = nx.planar_layout(G)  # Sắp xếp đồ thị theo dạng dễ đọc
nx.draw(G, pos, with_labels=True, node_size=3500, node_color="lightblue", font_size=10, edge_color="gray", arrows=True)
plt.title("Sơ đồ Quy Trình Thuê Thiết Bị - BuildIT (Dạng Khối Rõ Ràng)", fontsize=14)

# Lưu sơ đồ thành tệp
image_path_fixed = r"D:\01.UIT\07.HK7\HTQT.png"
plt.savefig(image_path_fixed, format="png")
plt.close()

# Trả về đường dẫn tải xuống
image_path_fixed
# Out:
# 'D:\\01.UIT\\07.HK7\\HTQT.png'
