# %%
import pandas as pd
import numpy as np

# %%
file_path = r"/python_in_data_analyst/laptops_test.csv"
df = pd.read_csv(file_path)

# %%
df.head(10)
# Out:
#   Manufacturer                         Model Name            Category  \
# 0           HP  15-bs053od (i7-7500U/6GB/1TB/W10)            Notebook
# 1         Asus                   Rog GL753VE-DS74              Gaming
# 2         Dell                      Inspiron 7579  2 in 1 Convertible
# 3      Toshiba                  Portege Z30-C-1CV            Notebook
# 4       Lenovo                  IdeaPad 320-15ABR            Notebook
# 5      Fujitsu                      LifeBook A556            Notebook
# 6      Toshiba                    Tecra A40-C-1KF            Notebook
# 7         Dell                      Inspiron 3567            Notebook
# 8           HP                        Probook 450            Notebook
# 9       Lenovo                 Legion Y520-15IKBN              Gaming
#
#   Screen Size                                     Screen  \
# 0       15.6"                                   1366x768
# 1       17.3"                          Full HD 1920x1080
# ...

# %%
header = df.columns

# %%
print(header)
# Out:
# Index(['Manufacturer', 'Model Name', 'Category', 'Screen Size', 'Screen',
#        'CPU', 'RAM', ' Storage', 'GPU', 'Operating System',
#        'Operating System Version', 'Weight', 'Price'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Price
# count  3.250000e+02
# mean   9.891671e+06
# std    5.943217e+06
# min    1.547208e+06
# 25%    5.317416e+06
# 50%    8.892000e+06
# 75%    1.332022e+07
# max    3.534570e+07

# %%
df1 = df.replace('?',np.nan)

# %%
df = df1.dropna(subset = ['Price'], axis=0)

# %%
df.describe()
# Out:
#               Price
# count  3.250000e+02
# mean   9.891671e+06
# std    5.943217e+06
# min    1.547208e+06
# 25%    5.317416e+06
# 50%    8.892000e+06
# 75%    1.332022e+07
# max    3.534570e+07

# %%
df.dropna(axis=1)
# Out:
#     Manufacturer                           Model Name            Category  \
# 0             HP    15-bs053od (i7-7500U/6GB/1TB/W10)            Notebook
# 1           Asus                     Rog GL753VE-DS74              Gaming
# 2           Dell                        Inspiron 7579  2 in 1 Convertible
# 3        Toshiba                    Portege Z30-C-1CV            Notebook
# 4         Lenovo                    IdeaPad 320-15ABR            Notebook
# ..           ...                                  ...                 ...
# 320       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 321       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 322       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 323           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 324         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#     Screen Size                                      Screen  \
# ...

# %%
df.describe(include="all")
# Out:
#        Manufacturer     Model Name  Category Screen Size             Screen  \
# count           325            325       325         325                325
# unique           12            197         6          10                 21
# top              HP  Inspiron 3567  Notebook       15.6"  Full HD 1920x1080
# freq             95              9       178         170                110
# mean            NaN            NaN       NaN         NaN                NaN
# std             NaN            NaN       NaN         NaN                NaN
# min             NaN            NaN       NaN         NaN                NaN
# 25%             NaN            NaN       NaN         NaN                NaN
# 50%             NaN            NaN       NaN         NaN                NaN
# 75%             NaN            NaN       NaN         NaN                NaN
# max             NaN            NaN       NaN         NaN                NaN
#
# ...

# %%
df.tail(20)
# Out:
#     Manufacturer                                 Model Name  \
# 305         Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 306       Lenovo                             Yoga 500-14ISK
# 307       Lenovo                             Yoga 900-13ISK
# 308       Lenovo                         IdeaPad 100S-14IBR
# 309           HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 310         Asus        X553SA-XX031T (N3050/4GB/500GB/W10)
# 311         Asus                       ZenBook UX305CA-UBM1
# 312         Dell                              Inspiron 3567
# 313         Acer                             Aspire ES1-531
# 314         Dell                              Inspiron 3552
# 315       Lenovo                         IdeaPad Y700-15ISK
# 316           HP                        Pavilion 15-AW003nv
# 317         Dell                              Inspiron 3567
# 318           HP                           Stream 11-Y000na
# 319         Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# ...

# %%
row_nan = df[df.isnull().any(axis=1)]

# %%
print(row_nan)
# Out:
#     Manufacturer                             Model Name            Category  \
# 14        Lenovo         V110-15IAP (N3350/4GB/128GB/No            Notebook
# 71          Asus                      Chromebook C202SA             Netbook
# 78            HP                                 250 G5            Notebook
# 83          Asus                      Rog G752VL-GC088D              Gaming
# 110           HP                          Chromebook 13            Notebook
# 112         Dell                          Inspiron 3552            Notebook
# 113           HP                                 250 G6            Notebook
# 124         Acer                          Chromebook 15            Notebook
# 136       Lenovo                              Yoga Book  2 in 1 Convertible
# 145         Dell                         Latitude E5570            Notebook
# 150       Lenovo                     Legion Y520-15IKBN              Gaming
# ...

# %%
df = df.drop(row_nan.index)

# %%
df
# Out:
#     Manufacturer                           Model Name            Category  \
# 0             HP    15-bs053od (i7-7500U/6GB/1TB/W10)            Notebook
# 1           Asus                     Rog GL753VE-DS74              Gaming
# 2           Dell                        Inspiron 7579  2 in 1 Convertible
# 3        Toshiba                    Portege Z30-C-1CV            Notebook
# 4         Lenovo                    IdeaPad 320-15ABR            Notebook
# ..           ...                                  ...                 ...
# 320       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 321       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 322       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 323           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 324         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#     Screen Size                                      Screen  \
# ...

# %%
df.describe()
# Out:
#               Price
# count  2.910000e+02
# mean   1.050033e+07
# std    5.946984e+06
# min    1.742832e+06
# 25%    6.059898e+06
# 50%    9.772308e+06
# 75%    1.364033e+07
# max    3.534570e+07

# %%
df["Price"].max()
# Out:
# np.float64(35345700.0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 291 entries, 0 to 324
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              291 non-null    object
#  1   Model Name                291 non-null    object
#  2   Category                  291 non-null    object
#  3   Screen Size               291 non-null    object
#  4   Screen                    291 non-null    object
#  5   CPU                       291 non-null    object
#  6   RAM                       291 non-null    object
#  7    Storage                  291 non-null    object
#  8   GPU                       291 non-null    object
#  9   Operating System          291 non-null    object
#  10  Operating System Version  291 non-null    object
#  11  Weight                    291 non-null    object
#  12  Price                     291 non-null    float64
# dtypes: float64(1), object(12)
# ...

# %%
df.dtypes
# Out:
# Manufacturer                 object
# Model Name                   object
# Category                     object
# Screen Size                  object
# Screen                       object
# CPU                          object
# RAM                          object
#  Storage                     object
# GPU                          object
# Operating System             object
# Operating System Version     object
# Weight                       object
# Price                       float64
# dtype: object

# %%
df.to_csv("laptop_test_cleaned.csv", index=False)
